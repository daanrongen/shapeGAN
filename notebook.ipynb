# %% [markdown]
# # Vector Shapes
# 1. Function that generates images (28x28) where the shapes have a colour and a position (x, y), and a size (width, height).
# 2. Write these images to .png files
# 3. Train a DCGAN on these images and mess around with the latent space to create new images.

# %%
import matplotlib.pyplot as plt

# %%
figure, axes = plt.subplots()
circle = plt.Circle(( 125, 125 ), 20.0)
  
axes.set_aspect(1)
plt.xlim(0, 256)
plt.ylim(0, 256)
axes.add_artist(circle)
plt.show()
